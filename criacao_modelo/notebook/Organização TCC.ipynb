# %% [markdown]
# ## Teórico

# %% [markdown]
# Exemplo TCC Lamartine
#
# 1. 2/3 páginas nome, banca, agradecimentos etc
# 2. Resumo
# 3. Abstract
# 4. Lista de ilustrações
# 5. Lista de Tabelas
# 6. Lista de Quadros
# 7. Lista de Abreviaturas e Siglas
# 8. Sumário
# 9. Introdução
#     * Justificativa
#     * Definição do Problema
#     * Questões de Pesquisas
#         * Quais são as métricas usadas
#         * Como são coletadas
#         * Fácil ser alteradas ?
#     * Objetivos Gerais
#     * Objetivos Específicos
# 10. Materiais e métodos
#     * Lista de tecnologias utilizadas
#     * Métodos
#         * Arquitetura (MVC) e explicação
#     * Testes utilizados
# 11. Plano de Desenvolvimento da Aplicação
#     * Requisitos Funcionais e Não-Funcionais
#     * Modelagem
#         * Diagrama de casos de uso
#         * Diagrama de classe
#         * Diagrama de arquitetura
#     * Plano de Testes (específico)
# 12. Desenvolvimento
#     * Ferramentas Utilizadas
#     * Passo a passo da construção do coração do script
# 13. Caso de Uso (com telas)
# 14. Conclusão
# 15. Referências Bibliográficas
#
#
# * Questões:
#     * Será necessário o referencial teórico?
#
#
#
# O que já temos?
# * Itens 1-8 serão feitos no final
# * Introdução
#     * Justificativa                      -> OK
#     * Definição do Problema              -> OK
#     * Questões de Pesquisas              -> Verificar SE faz sentido
#     * Objetivos Gerais                   -> OK
#     * Objetivos Específicos              -> OK
# * Materiais e métodos
#     * Lista de tecnologias utilizadas    -> Verificar e fazer
#     * Métodos                            -> Verificar e fazer
#     * Testes utilizados                  -> Verificar e fazer
# * Plano de Desenvolvimento da Aplicação
#     * RF e RNF                           -> OK
#     * Modelagem
#         * Diagrama de casos de uso       -> OK
#         * Diagrama de classe             -> Refatorar
#         * Diagrama de arquitetura        -> Verificar SE faz sentido
#     * Plano de Testes (específico)       -> Verificar SE faz sentido
# * Desenvolvimento
#     * Ferramentas Utilizadas             -> Verificar e fazer
#     * Passo a passo do script            -> Verificar e fazer
# * Casos de Uso com telas                 -> 50%, faltam as telas
# * Conclusão                              -> Verificar e fazer
# * Referências                            -> Tem, apenas corrigir depois
#
#
#
# Divisão das atividades:
# * Itens 1-8, deixar para o final
# * Se necessário Introdução/Questões de Pesquisa (metodologia) -> Paloma
# * Se necessário o referencial teórico -> Carol
# * Materiais e métodos -> Leonardo
# * Plano de Desenvolvimento da aplicação - Diagrama de classe -> Daniel
# * Se necessário Plano de Testes (específico) -> Paloma
# * Desenvolvimento/Ferramentas -> Leonardo
# * Desenvolvimento/Passo a Passo Script -> Carol
# * Caso de Uso com telas / Conclusão -> Daniel
#
#
#
# Divisão das atividades futuras
# * Formatação ABNT e item 1 -> Paloma
# * Resumo / Abstract -> Carol
# * Listas e Sumário -> Daniel/Leonardo

# %% [markdown]
# ## Prático

# %% [markdown]
# 1. Imagens
#     * Validação de Imagens (com o Lamartine), x15
#         * Avaliar peso das imagens
#         * Se realmente é necessário
#     * Treinamento de 8x
#     * Abaixar resolução das imagens via Pillow
# 2. Sistema Desktop
#     * Front-End
#         * Detalhamento das telas
#         * Fluxo do aplicativo
#         * Disposição dos componentes
#         * Utilização do Qt e QtDesigner
#     * Back-End
#         * Componentes dev
#             * Python (linguagem)       -> 3.7
#             * PyQt5 (lib/framework)    -> 5.13.0
#             * cx_Freeze (.py -> .exe)  -> 6.0.0
#         * Utilização MVC (dev)
#         * Distribuição -> um script só
#         * Realizar os triggers dos botões
#         * Inserir os métodos principais
#             * Montar/carregar o modelo (atenção: definir se utilizaremos vários modelos (x2, x4) OU via Pillow)
#             * Processar a imagem
#             * Mostrar a imagem
#         * Diagrama de classe
#             * O antigo não irá prestar/casar com o código
# 3. Testes
#     * Numero de DPI da imagem
#     * Número de pixels
#     * Coleta de opiniões
#     * Registro de resultados com diferentes características na rede
#     * Teste de tempo
#
#
#
# O que já temos?
# * Script para carregar o modelo
# * Script para conversão de imagem
